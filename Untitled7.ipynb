# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('amazon_sales_dataset.csv')
df.head(10)
# Out:
#    order_id  order_date  product_id product_category   price  \
# 0         1  2022-04-13        2637            Books  128.75
# 1         2  2023-03-12        2300          Fashion  302.60
# 2         3  2022-09-28        3670           Sports  495.80
# 3         4  2022-04-17        2522            Books  371.95
# 4         5  2022-03-13        1717           Beauty  201.68
# 5         6  2023-12-02        1777           Sports  385.17
# 6         7  2022-01-21        4068            Books   15.78
# 7         8  2023-09-07        3537          Fashion  111.59
# 8         9  2022-05-02        3262            Books  373.62
# 9        10  2023-04-12        4174           Sports  134.81
#
#    discount_percent  quantity_sold customer_region    payment_method  rating  \
# 0                10              4   North America               UPI     3.5
# 1                20              5            Asia       Credit Card     3.7
# 2                20              2          Europe               UPI     4.4
# 3                15              4     Middle East               UPI     5.0
# 4                 0              4     Middle East               UPI     4.6
# 5                30              3            Asia            Wallet     3.8
# 6                 0              5            Asia               UPI     1.6
# 7                30              4     Middle East               UPI     3.4
# 8                 0              4            Asia            Wallet     2.8
# 9                15              2     Middle East  Cash on Delivery     2.0
#
#    review_count  discounted_price  total_revenue
# 0           443            115.88         463.52
# 1           475            242.08        1210.40
# 2           183            396.64         793.28
# 3           212            316.16        1264.64
# 4           308            201.68         806.72
# 5           489            269.62         808.86
# 6           415             15.78          78.90
# 7           143             78.11         312.44
# 8           497            373.62        1494.48
# 9            25            114.59         229.18

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# product_id            int64
# product_category     object
# price               float64
# discount_percent      int64
# quantity_sold         int64
# customer_region      object
# payment_method       object
# rating              float64
# review_count          int64
# discounted_price    float64
# total_revenue       float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# product_id                   int64
# product_category            object
# price                      float64
# discount_percent             int64
# quantity_sold                int64
# customer_region             object
# payment_method              object
# rating                     float64
# review_count                 int64
# discounted_price           float64
# total_revenue              float64
# dtype: object

# %%
df.isna().sum()
# Out:
# order_id            0
# order_date          0
# product_id          0
# product_category    0
# price               0
# discount_percent    0
# quantity_sold       0
# customer_region     0
# payment_method      0
# rating              0
# review_count        0
# discounted_price    0
# total_revenue       0
# dtype: int64

# %%
df_missing = df.copy()
df_missing.loc[0:5, 'total_revenue'] = np.nan   # nan stands for "Not a Number"
df_missing.isna().sum()
# Out:
# order_id            0
# order_date          0
# product_id          0
# product_category    0
# price               0
# discount_percent    0
# quantity_sold       0
# customer_region     0
# payment_method      0
# rating              0
# review_count        0
# discounted_price    0
# total_revenue       6
# dtype: int64

# %%
df_removed = df_missing.dropna()
df_removed.shape
# Out:
# (49994, 13)

# %%
df_missing.shape
# Out:
# (50000, 13)

# %%
df_imputed_mean = df_missing.copy()
df_imputed_mean['total_revenue'].fillna(df_imputed_mean['total_revenue'].mean(), inplace=True)
df_imputed_mean.head(10)
# Out:
# /tmp/ipykernel_1659/1036270679.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed_mean['total_revenue'].fillna(df_imputed_mean['total_revenue'].mean(), inplace=True)
#    order_id order_date  product_id product_category   price  discount_percent  \
# 0         1 2022-04-13        2637            Books  128.75                10
# 1         2 2023-03-12        2300          Fashion  302.60                20
# 2         3 2022-09-28        3670           Sports  495.80                20
# 3         4 2022-04-17        2522            Books  371.95                15
# 4         5 2022-03-13        1717           Beauty  201.68                 0
# 5         6 2023-12-02        1777           Sports  385.17                30
# 6         7 2022-01-21        4068            Books   15.78                 0
# 7         8 2023-09-07        3537          Fashion  111.59                30
# 8         9 2022-05-02        3262            Books  373.62                 0
# 9        10 2023-04-12        4174           Sports  134.81                15
#
#    quantity_sold customer_region    payment_method  rating  review_count  \
# 0              4   North America               UPI     3.5           443
# 1              5            Asia       Credit Card     3.7           475
# 2              2          Europe               UPI     4.4           183
# 3              4     Middle East               UPI     5.0           212
# 4              4     Middle East               UPI     4.6           308
# 5              3            Asia            Wallet     3.8           489
# 6              5            Asia               UPI     1.6           415
# 7              4     Middle East               UPI     3.4           143
# 8              4            Asia            Wallet     2.8           497
# 9              2     Middle East  Cash on Delivery     2.0            25
#
#    discounted_price  total_revenue
# 0            115.88     657.303403
# 1            242.08     657.303403
# 2            396.64     657.303403
# 3            316.16     657.303403
# 4            201.68     657.303403
# 5            269.62     657.303403
# 6             15.78      78.900000
# 7             78.11     312.440000
# 8            373.62    1494.480000
# 9            114.59     229.180000

# %%
df_imputed_mean.shape
# Out:
# (50000, 13)

# %%
df_missing.shape
# Out:
# (50000, 13)

# %%
df_imputed_median = df_missing.copy()
df_imputed_median['total_revenue'].fillna(df_imputed_median['total_revenue'].median(), inplace=True)
df_imputed_median.head(10)
# Out:
# /tmp/ipykernel_1659/1098067718.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed_median['total_revenue'].fillna(df_imputed_median['total_revenue'].median(), inplace=True)
#    order_id order_date  product_id product_category   price  discount_percent  \
# 0         1 2022-04-13        2637            Books  128.75                10
# 1         2 2023-03-12        2300          Fashion  302.60                20
# 2         3 2022-09-28        3670           Sports  495.80                20
# 3         4 2022-04-17        2522            Books  371.95                15
# 4         5 2022-03-13        1717           Beauty  201.68                 0
# 5         6 2023-12-02        1777           Sports  385.17                30
# 6         7 2022-01-21        4068            Books   15.78                 0
# 7         8 2023-09-07        3537          Fashion  111.59                30
# 8         9 2022-05-02        3262            Books  373.62                 0
# 9        10 2023-04-12        4174           Sports  134.81                15
#
#    quantity_sold customer_region    payment_method  rating  review_count  \
# 0              4   North America               UPI     3.5           443
# 1              5            Asia       Credit Card     3.7           475
# 2              2          Europe               UPI     4.4           183
# 3              4     Middle East               UPI     5.0           212
# 4              4     Middle East               UPI     4.6           308
# 5              3            Asia            Wallet     3.8           489
# 6              5            Asia               UPI     1.6           415
# 7              4     Middle East               UPI     3.4           143
# 8              4            Asia            Wallet     2.8           497
# 9              2     Middle East  Cash on Delivery     2.0            25
#
#    discounted_price  total_revenue
# 0            115.88         505.38
# 1            242.08         505.38
# 2            396.64         505.38
# 3            316.16         505.38
# 4            201.68         505.38
# 5            269.62         505.38
# 6             15.78          78.90
# 7             78.11         312.44
# 8            373.62        1494.48
# 9            114.59         229.18

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['total_revenue'])
plt.title("Boxplot of Revenue")
plt.show()

# %%
Q1 = df['total_revenue'].quantile(0.25)
Q3 = df['total_revenue'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['total_revenue'] < lower) | (df['total_revenue'] > upper)]
outliers.head()
# Out:
#      order_id order_date  product_id product_category   price  \
# 204       205 2023-01-21        1256   Home & Kitchen  469.04
# 216       217 2022-08-13        2764      Electronics  483.28
# 291       292 2022-04-14        1917            Books  489.42
# 300       301 2023-12-07        2959            Books  490.29
# 466       467 2022-03-10        2000   Home & Kitchen  443.64
#
#      discount_percent  quantity_sold customer_region payment_method  rating  \
# 204                 5              5   North America            UPI     1.8
# 216                 0              5            Asia            UPI     2.4
# 291                 5              5            Asia     Debit Card     2.2
# 300                 5              5     Middle East            UPI     1.9
# 466                 5              5   North America         Wallet     1.3
#
#      review_count  discounted_price  total_revenue
# 204            87            445.59        2227.95
# 216           190            483.28        2416.40
# 291           494            464.95        2324.75
# 300           429            465.78        2328.90
# 466           166            421.46        2107.30

# %%
df_no_outliers = df[(df['total_revenue'] >= lower) & (df['total_revenue'] <= upper)]

print("Original shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (50000, 13)
# After removing outliers: (49248, 13)

# %%
lower_cap = df['total_revenue'].quantile(0.05)
upper_cap = df['total_revenue'].quantile(0.95)

df_capped = df.copy()
df_capped['total_revenue'] = df_capped['total_revenue'].clip(lower_cap, upper_cap)

# %%
df_capped.shape
# Out:
# (50000, 13)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df_capped['total_revenue'])
plt.title("Boxplot of Revenue")
plt.show()

# %%
df[['total_revenue', 'quantity_sold']].head(10)
# Out:
#    total_revenue  quantity_sold
# 0         463.52              4
# 1        1210.40              5
# 2         793.28              2
# 3        1264.64              4
# 4         806.72              4
# 5         808.86              3
# 6          78.90              5
# 7         312.44              4
# 8        1494.48              4
# 9         229.18              2

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_scaled = df[['total_revenue', 'quantity_sold']].copy()
df_scaled[['total_revenue', 'quantity_sold']] = scaler.fit_transform(df_scaled)

df_scaled.head()
# Out:
#    total_revenue  quantity_sold
# 0       0.184188           0.75
# 1       0.483454           1.00
# 2       0.316319           0.25
# 3       0.505187           0.75
# 4       0.321704           0.75

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_standardized = df[['total_revenue', 'quantity_sold']].copy()
df_standardized[['total_revenue', 'quantity_sold']] = scaler.fit_transform(df_standardized)

df_standardized.head()
# Out:
#    total_revenue  quantity_sold
# 0      -0.368310       0.706945
# 1       1.051024       1.413465
# 2       0.258350      -0.706097
# 3       1.154099       0.706945
# 4       0.283891       0.706945

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_standardized[['total_revenue', 'quantity_sold']].corr(),
            annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap (Before PCA)")
plt.show()

# %%
from sklearn.decomposition import PCA

X = df_standardized[['total_revenue', 'quantity_sold']]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.79720208 0.20279792]
